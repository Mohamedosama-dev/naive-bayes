# %%
import  wikipediaapi
import pickle
import re
import nltk

from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\E_Hom\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
class NaiveBayesClassifier:
    def __init__(self):
        self.classes = []
        self.class_probabilities = {}
        self.word_counts = {}
        self.word_probabilities = {}

    def load_data(self, train_domains, test_domains):

      # Initialize the Wikipedia API
      wiki = wikipediaapi.Wikipedia('en')

    # Define the domains and titles of the documents to download
      domains = {
        'planes': ['Aircraft', 'Boeing 747', 'Airbus A380', 'Wright Brothers', 'Air traffic control', 'Jet engine',
    'Propeller', 'Glider', 'Flight simulator', 'Military aircraft'],
        'tech': ['Machine_learning', 'Data mining', 'Artificial intelligence', 'Neural network', 'Deep learning', 'Cybersecurity',
    'Internet of Things', 'Augmented Reality', 'Cryptocurrency', 'Virtual Reality']
    }


      # Download the training documents
      training_data = []
      for domain in train_domains:
          for title in domains[domain]:
              page = wiki.page(title)
              if page.exists():
                  text = page.text[:2000]  # take only the first 2000 characters 
                  training_data.append((text, domain))
              if len(training_data) >= 5 * len(train_domains):  # Stop downloading when 5 docs per domain are downloaded
                  break
          print(f"Loaded {len(training_data)} training documents for '{domain}' domain")


      # Download the test documents
      test_data = []
      for domain in test_domains:
          title = domains[domain][0]  # Choose the first title as the test document
          page = wiki.page(title)
          if page.exists():
              text = page.text[:1000]  # take only the first 10000 characters (about 100 words)
              test_data.append((text, domain))
          else:
              print(f"Error: Could not find test document for '{domain}' domain")
    
      return training_data, test_data


    def class_prob(self, doc_label):
       
             probability = self.class_probabilities[doc_label]
            
             return self.class_probabilities[doc_label]
    

    def preprocess(self, doc):
      # remove punctuation and lowercase all words
      doc = re.sub(r'[^\w\s]', ' ', doc)
      doc = doc.lower()
      # remove digits
      doc = re.sub(r'\d+', '', doc)
      # remove stop words
      stop_words = set(stopwords.words('english'))
      words = doc.split()
      words = [word for word in words if word not in stop_words]
      doc = ' '.join(words)
      # remove extra whitespace
      doc = re.sub(r'\s+', ' ', doc).strip()
      return doc

    def get_tokens(self, doc):
    # preprocess the document
      preprocessed_doc = self.preprocess(doc)
      # initialize variables
      start = 0
      tokens = []
    # loop through each character in the preprocessed document
      for i in range(len(preprocessed_doc)):
          # check if the current character is whitespace or punctuation
          if preprocessed_doc[i].isspace() or preprocessed_doc[i] in ('!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~'):
              # get the current token and add it to the list of tokens
              token = preprocessed_doc[start:i]
              if token:
                  tokens.append(token)
              # update the start index
              start = i + 1
    # get the final token and add it to the list of tokens
      final_token = preprocessed_doc[start:]
      if final_token:
          tokens.append(final_token)
      # return the set of unique tokens in the document
      unique_tokens = set(tokens)
      print("unique word",unique_tokens)
      return unique_tokens
   

    

    def conditional_prob(self, word, label):
        # check if the word, label tuple is in the word_probabilities dictionary
        if (label, word) in self.word_probabilities:
            # if it is, retrieve the probability from the dictionary and print it
            probability = self.word_probabilities[(label, word)]
            print(f"Probability of word '{word}' given label '{label}': {probability}")
            # return the probability
            return probability
        else:
            # if the word, label tuple is not in the dictionary, return 0
            return 0


    def train(self, training_data):
        # calculate class probabilities
        total_docs = len(training_data)
        # iterate over the possible classes
        for c in self.classes:
            # count the number of documents in this class
            docs_in_class = len([d for d in training_data if d[1] == c])
            # calculate the probability of this class by dividing the number of documents in this class by the total number of documents
            self.class_probabilities[c] = docs_in_class / total_docs
        # count words
        # iterate over the training data
        for doc, label in training_data:
            # preprocess the document
            preprocessed_doc = self.preprocess(doc)
            # split the document into tokens
            tokens = self.get_tokens(preprocessed_doc)
            # iterate over the tokens
            for token in tokens:
                # if the label is not already in the word_counts dictionary, add it
                if label not in self.word_counts:
                    self.word_counts[label] = {}
                # if the token is not already in the word_counts dictionary for this label, add it
                if token not in self.word_counts[label]:
                    self.word_counts[label][token] = 0
                # increment the count for this word in this label
                self.word_counts[label][token] += 1
        # calculate word probabilities
        # iterate over the possible labels
        for label in self.classes:
            # calculate the total number of words in this label
            total_words_in_class = sum(self.word_counts[label].values())
            # iterate over the words for this label
            for word in self.word_counts[label]:
                # calculate the probability of this word for this label using the count and Laplace smoothing
                self.word_probabilities[(label, word)] = (self.word_counts[label][word] + 1) / (total_words_in_class + len(self.word_counts[label]))


    # This method saves the trained model to a file
    def save_model(self, filename):
        # Open a file in write mode and use pickle to dump the model
        # classes, class_probabilities, and word_probabilities into the file.
        with open(filename, 'wb') as f:
            pickle.dump((self.classes, self.class_probabilities, self.word_probabilities), f)

    # This method loads a trained model from a file
    def load_model(self, filename):
        # Open a file in read mode and use pickle to load the model classes,
        # class_probabilities, and word_probabilities from the file.
        with open(filename, 'rb') as f:
            self.classes, self.class_probabilities, self.word_probabilities = pickle.load(f)

    # This method takes in some test data and returns the predicted labels for each document
    def predict(self, test_data):
        # Initialize an empty list to store predictions
        predictions = []
        # Loop through each document and its actual label in the test data
        for doc, actual_label in test_data:
            # Preprocess the document (e.g. remove stop words, punctuation, etc.)
            preprocessed_doc = self.preprocess(doc)
            # Get the tokens in the preprocessed document
            tokens = self.get_tokens(preprocessed_doc)
            # Initialize a dictionary to store scores for each class
            scores = {c: 0 for c in self.classes}
            # Loop through each token in the document
            for token in tokens:
                # For each class, add the conditional probability of the token given the class to the score
                for c in self.classes:
                    scores[c] += self.conditional_prob(token, c)
            # For each class, add the class probability to the score
            for c in self.classes:
                scores[c] += self.class_prob(c)
            # Predict the label with the highest score
            predicted_label = max(scores, key=scores.get)
            # Add the preprocessed document, predicted label, and actual label to the predictions list
            predictions.append((preprocessed_doc, predicted_label, actual_label))
        # Return the list of predictions
        return predictions

# %%
# create NaiveBayesClassifier instance
nb_classifier = NaiveBayesClassifier()

# define the classes
classes = ['planes', 'tech']

# set the classes in the classifier
nb_classifier.classes = classes

# %%
# load the training and test data
train_data, test_data = nb_classifier.load_data(classes, classes)

# train the model
nb_classifier.train(train_data)
# Out:
# Loaded 10 training documents for 'planes' domain
# Loaded 11 training documents for 'tech' domain
# unique word {'world', 'methods', 'prior', 'gravity', 'model', 'china', 'airfoil', 'centuries', 'place', 'helium', 'led', 'also', 'able', 'common', 'th', 'usage', 'vehicles', 'era', 'hydrogen', 'thrust', 'pilot', 'flight', 'times', 'flown', 'remotely', 'paramotors', 'criteria', 'counters', 'activity', 'crewed', 'building', 'float', 'ships', 'war', 'surrounding', 'weight', 'advances', 'safe', 'rd', 'technical', 'aerostats', 'whereas', 'postwar', 'five', 'took', 'direct', 'jet', 'include', 'manned', 'hot', 'self', 'examples', 'great', 'history', 'one', 'sky', 'stories', 'fly', 'adds', 'including', 'gliders', 'wars', 'lanterns', 'ascent', 'much', 'eras', 'designing', 'different', 'century', 'second', 'descent', 'large', 'engines', 'ancient', 'aviation', 'celebrations', 'airplanes', 'controlled', 'low', 'flying', 'classified', 'added', 'characterized', 'use', 'bc', 'day', 'vehicle', 'either', 'lighter', 'developed', 'larger', 'two', 'aeronautics', 'consequently', 'craft', 'less', 'blimps', 'onboard', 'type', 'many', 'water', 'balloons', 'human', 'surrounds', 'static', 'used', 'may', 'modern', 'buoyancy', 'gas', 'earliest', 'go', 'cases', 'unmanned', 'air', 'filled', 'force', 'airships', 'small', 'downward', 'dynamic', 'using', 'computers', 'age', 'displaces', 'cells', 'helicopters', 'pioneers', 'cultural', 'present', 'structure', 'called', 'invented', 'science', 'first', 'aerial', 'density', 'primarily', 'propulsion', 'relatively', 'support', 'back', 'others', 'experiments', 'dense', 'canopies', 'way', 'divided', 'gaining', 'however', 'lift', 'aircraft'}
# unique word {'world', 'general', 'pronounced', 'states', 'would', 'airplane', 'legs', 'place', 'double', 'year', 'turbofan', 'supported', 'nautical', 'miles', 'whitney', 'service', 'flight', 'times', 'powerful', 'typically', 'left', 'aisle', 'heavy', 'pounds', 'converted', 'rolled', 'april', 'september', 'bypass', 'main', 'cargo', 'plant', 'partial', 'building', 'classes', 'body', 'weight', 'wheel', 'door', 'jumbo', 'thought', 'design', 'took', 'sp', 'jet', 'united', 'ordered', 'late', 'raised', 'could', 'certified', 'rolls', 'abreast', 'accommodates', 'engine', 'boeing', 'initial', 'installing', 'pan', 'powered', 'upper', 'large', 'engines', 'front', 'everett', 'travel', 'speed', 'supersonic', 'airplanes', 'economy', 'january', 'wanted', 'transports', 'h', 'mtow', 'cruise', 'kn', 'stretched', 'agreed', 'original', 'superseded', 'engined', 'wide', 'shortened', 'followed', 'pratt', 'jtd', 'introducing', 'maximum', 'largest', 'range', 'cf', 'introduced', 'four', 'size', 'cockpit', 'built', 'electric', 'seat', 'october', 'cost', 'initially', 'landing', 'program', 'longer', 'sweep', 'seating', 'rb', 'joe', 'royce', 'develop', 'takeoff', 'passengers', 'freighter', 'called', 'first', 'increasing', 'long', 'february', 'heavier', 'commercial', 'twin', 'gear', 'mach', 'airliner', 'km', 'custom', 'variants', 'entered', 'deck', 'high', 'volume', 'sutter', 'manufactured', 'ten', 'development', 'three', 'wing', 'allowing', 'reduce', 'bogie', 'designed', 'eventually', 'aircraft', 'december'}
# unique word {'world', 'market', 'order', 'would', 'full', 'double', 'delayed', 'year', 'challenge', 'led', 'began', 'complete', 'recouped', 'million', 'peaked', 'end', 'work', 'passenger', 'service', 'flight', 'per', 'secret', 'obtained', 'costs', 'april', 'length', 'body', 'rd', 'almost', 'designated', 'fleet', 'presented', 'nmi', 'jet', 'produced', 'trent', 'toulouse', 'wiring', 'mid', 'alliance', 'reduced', 'axx', 'operators', 'studies', 'started', 'administration', 'certified', 'rolls', 'due', 'roeder', 'faa', 'engine', 'boeing', 'initial', 'investment', 'powered', 'st', 'large', 'completed', 'electrical', 'singapore', 'aviation', 'billion', 'agency', 'haul', 'january', 'fatalities', 'customer', 'background', 'engineers', 'wide', 'flights', 'uhca', 'developed', 'difficulties', 'two', 'produc', 'airbus', 'dominance', 'last', 'certificate', 'ultra', 'maximum', 'announced', 'type', 'project', 'production', 'delivered', 'largest', 'range', 'launched', 'typical', 'hull', 'block', 'gp', 'october', 'losses', 'safety', 'seating', 'doubled', 'quadjet', 'received', 'providing', 'royce', 'global', 'capacity', 'years', 'passengers', 'us', 'first', 'airlines', 'jean', 'long', 'unveiled', 'february', 'emirates', 'airliner', 'federal', 'km', 'european', 'entered', 'deck', 'prototype', 'high', 'programme', 'development', 'turbofans', 'worldwide', 'easa', 'however', 'aircraft', 'december', 'hours'}
# unique word {'world', 'printing', 'known', 'airplane', 'possible', 'wings', 'also', 'work', 'beginning', 'generally', 'patent', 'working', 'pilot', 'flight', 'powerful', 'sustained', 'wilbur', 'august', 'time', 'april', 'equilibrium', 'standard', 'wrights', 'north', 'hawk', 'building', 'machinery', 'experimenters', 'machine', 'essential', 'emphasis', 'design', 'effectively', 'mechanical', 'put', 'south', 'developing', 'based', 'iii', 'could', 'enabled', 'particular', 'powered', 'focused', 'differed', 'belief', 'engines', 'flyer', 'fixed', 'aviation', 'control', 'successful', 'system', 'presses', 'controlled', 'january', 'invent', 'flying', 'american', 'method', 'aeronautical', 'creation', 'remains', 'manipulated', 'propellers', 'solving', 'wind', 'vehicle', 'flights', 'make', 'followed', 'ii', 'developed', 'accurate', 'running', 'unstable', 'credited', 'kill', 'motor', 'kinds', 'brothers', 'key', 'tunnel', 'inventing', 'significantly', 'problem', 'controls', 'invention', 'claim', 'practical', 'truly', 'rather', 'influenced', 'kitty', 'may', 'reliable', 'built', 'mi', 'longer', 'air', 'carolina', 'aerodynamic', 'small', 'breakthrough', 'using', 'steer', 'bicycles', 'maintain', 'collected', 'efficient', 'surfaces', 'orville', 'u', 'home', 'pioneers', 'years', 'wright', 'first', 'made', 'gained', 'con', 'heavier', 'hills', 'motors', 'skills', 'success', 'approach', 'shop', 'operated', 'devil', 'km', 'data', 'ohio', 'dayton', 'wing', 'three', 'axis', 'enabling', 'aircraft', 'december'}
# unique word {'world', 'emergency', 'states', 'known', 'required', 'must', 'airspace', 'weather', 'also', 'service', 'pilot', 'flight', 'times', 'expedite', 'advisories', 'operating', 'organization', 'primary', 'amount', 'authority', 'flow', 'aerodrome', 'civil', 'military', 'practice', 'empty', 'safe', 'cto', 'airport', 'international', 'region', 'maintains', 'services', 'direct', 'organize', 'non', 'provides', 'united', 'english', 'provided', 'pursuant', 'purpose', 'space', 'operators', 'based', 'history', 'native', 'upon', 'communicate', 'request', 'divisions', 'extent', 'depending', 'rules', 'aviation', 'control', 'language', 'collisions', 'controlled', 'ground', 'atc', 'requirements', 'monitor', 'deviate', 'within', 'location', 'commissioned', 'class', 'final', 'obey', 'disregard', 'either', 'wooden', 'developed', 'croydon', 'station', 'tower', 'traffic', 'discretion', 'operations', 'command', 'type', 'windows', 'many', 'conducted', 'four', 'operation', 'used', 'icao', 'may', 'instructions', 'ft', 'information', 'air', 'private', 'basic', 'controllers', 'enforces', 'given', 'minimum', 'maintain', 'prevent', 'section', 'london', 'called', 'assigned', 'ensure', 'first', 'radar', 'issue', 'around', 'advisory', 'february', 'support', 'separation', 'commercial', 'sides', 'pilots', 'provide', 'countries', 'high', 'three', 'worldwide', 'radio', 'introduce', 'hut', 'however', 'aircraft'}
# unique word {'general', 'necessary', 'reaction', 'would', 'known', 'hours', 'required', 'subsonic', 'pulse', 'alexandria', 'complex', 'turn', 'journey', 'turbofan', 'th', 'early', 'dates', 'work', 'previously', 'thrust', 'idea', 'flight', 'per', 'de', 'typically', 'compressor', 'permitted', 'device', 'ge', 'process', 'bypass', 'fruition', 'heated', 'distances', 'advances', 'give', 'technical', 'inefficient', 'routine', 'went', 'shutdowns', 'jet', 'hero', 'effect', 'efficiency', 'include', 'generates', 'hybrid', 'term', 'mechanical', 'late', 'history', 'combustion', 'havilland', 'thermodynamic', 'engine', 'century', 'principle', 'described', 'powered', 'st', 'engines', 'greatly', 'internal', 'travel', 'speed', 'refers', 'ramjets', 'broad', 'similar', 'piston', 'stops', 'come', 'breathing', 'use', 'rudimentary', 'engined', 'distance', 'rocket', 'rotating', 'vehicle', 'turbine', 'make', 'applications', 'moving', 'brayton', 'turbojet', 'fuel', 'multiple', 'aeolipile', 'nozzle', 'instead', 'less', 'higher', 'n', 'demonstration', 'propelling', 'type', 'water', 'aeroengines', 'typical', 'consumption', 'egypt', 'used', 'may', 'modern', 'fast', 'gas', 'feature', 'electric', 'cycle', 'jetliner', 'definition', 'air', 'new', 'propeller', 'combined', 'lbf', 'discharging', 'usually', 'airliners', 'providing', 'greater', 'decreased', 'reliability', 'made', 'ghost', 'propulsion', 'long', 'relatively', 'twin', 'back', 'ramjet', 'transatlantic', 'scramjets', 'ram', 'high', 'power', 'however', 'aircraft', 'leftover'}
# unique word {'angle', 'employed', 'fluid', 'known', 'form', 'china', 'centuries', 'difference', 'set', 'duct', 'propel', 'toy', 'early', 'special', 'enjoyed', 'thrust', 'beginning', 'working', 'though', 'balance', 'blades', 'screw', 'screws', 'colloquially', 'irrigation', 'taking', 'approximately', 'device', 'segmented', 'toogood', 'derived', 'side', 'became', 'study', 'wheel', 'later', 'leonardo', 'ad', 'practice', 'arc', 'canvas', 'archimedes', 'exerts', 'rotational', 'space', 'create', 'pitch', 'one', 'history', 'origin', 'starts', 'upon', 'adopted', 'shaft', 'movement', 'principle', 'large', 'ship', 'effective', 'innovation', 'bailing', 'blade', 'application', 'flying', 'marine', 'single', 'helicopter', 'da', 'propellers', 'sketches', 'bc', 'spiral', 'rotating', 'causes', 'often', 'boats', 'bernoulli', 'rotated', 'airscrew', 'theoretical', 'two', 'pump', 'least', 'keep', 'horizontal', 'linear', 'egyptians', 'water', 'introduced', 'hub', 'care', 'copter', 'pressure', 'used', 'waterjet', 'drive', 'air', 'propeller', 'probably', 'force', 'nearly', 'radiating', 'presenting', 'proposed', 'using', 'sculling', 'involved', 'shaped', 'motion', 'surfaces', 'pr', 'forces', 'spirals', 'extension', 'overhead', 'called', 'moved', 'always', 'famously', 'helical', 'around', 'propulsion', 'attaching', 'bamboo', 'pipe', 'vinci', 'hays', 'hollow', 'developments', 'c', 'axis', 'boat', 'lift', 'aircraft'}
# unique word {'world', 'rapid', 'model', 'toy', 'undercarriage', 'fluffy', 'also', 'winged', 'norfolcensis', 'thrust', 'flight', 'automobiles', 'warcraft', 'album', 'song', 'transit', 'submarine', 'biak', 'paper', 'walking', 'gimli', 'mahogany', 'crows', 'transport', 'calhoun', 'framed', 'foot', 'military', 'members', 'without', 'intended', 'gameplay', 'macintosh', 'bus', 'counting', 'troops', 'powertrain', 'recreation', 'game', 'glider', 'title', 'eight', 'breviceps', 'computing', 'mammals', 'generated', 'life', 'zone', 'video', 'abidi', 'sight', 'animals', 'squirrel', 'sport', 'emblem', 'games', 'petaurus', 'successful', 'system', 'families', 'apple', 'boyfr', 'source', 'hacker', 'gliding', 'northern', 'name', 'biacensis', 'within', 'generate', 'belfast', 'automating', 'fabric', 'rocket', 'vehicle', 'ireland', 'suborder', 'lands', 'running', 'featuring', 'unpowered', 'fuel', 'motor', 'two', 'volans', 'refer', 'petauroides', 'acrobates', 'changing', 'least', 'pygmy', 'gracilis', 'music', 'glided', 'launched', 'used', 'phalangeriformes', 'may', 'buoyancy', 'valentine', 'canada', 'marsupial', 'landing', 'john', 'combat', 'bot', 'feathertail', 'air', 'band', 'propelled', 'internet', 'bloody', 'behind', 'usually', 'possum', 'sugar', 'greater', 'yellow', 'unframed', 'pygmaeus', 'tokio', 'made', 'conway', 'primarily', 'heavier', 'hang', 'ep', 'routinely', 'equipment', 'paraglider', 'underwater', 'person', 'pattern', 'rigid', 'wing', 'bellied', 'power', 'updraft', 'sailplane', 'walkalong', 'aircraft', 'australis'}
# unique word {'world', 'general', 'environment', 'angle', 'tonneau', 'regulations', 'full', 'created', 'reach', 'laffont', 'turbulence', 'reasons', 'etc', 'systems', 'training', 'also', 'meaning', 'simulators', 'external', 'pilot', 'flight', 'de', 'replicating', 'device', 'initiative', 'bullets', 'time', 'specialist', 'reacts', 'named', 'war', 'deflection', 'military', 'flies', 'practice', 'technical', 'require', 'design', 'allow', 'involves', 'seems', 'past', 'english', 'react', 'artificially', 'term', 'based', 'history', 'corresponds', 'fly', 'including', 'conditions', 'antoinette', 'handled', 'precursor', 'characteristics', 'shear', 'recent', 'different', 'qualities', 'sometimes', 'control', 'language', 'skill', 'simulation', 'ground', 'ahead', 'throughout', 'wind', 'creates', 'clavenad', 'mimic', 'applications', 'clolus', 'requires', 'area', 'moving', 'documents', 'french', 'gunnery', 'commanders', 'kinds', 'refer', 'research', 'various', 'aiming', 'controls', 'simulator', 'behavior', 'used', 'firing', 'may', 'govern', 'built', 'generic', 'equations', 'fstd', 'lieutenant', 'target', 'vicinity', 'air', 'purposes', 'specifically', 'effects', 'shooting', 'slightly', 'precipitation', 'cloud', 'lead', 'carry', 'definitions', 'called', 'first', 'barrel', 'handling', 'procedures', 'density', 'phrase', 'pilots', 'factors', 'closely', 'company', 'includes', 'devices', 'mainly', 'development', 'variety', 'referred', 'gunner', 'aircraft'}
# unique word {'world', 'states', 'several', 'prussian', 'division', 'operate', 'cities', 'enemy', 'acquired', 'th', 'hydrogen', 'service', 'flight', 'flew', 'typically', 'blimp', 'duties', 'signal', 'army', 'time', 'served', 'primary', 'became', 'war', 'continued', 'ordnance', 'military', 'civilian', 'legal', 'destroy', 'handful', 'quickly', 'non', 'united', 'rotary', 'hot', 'self', 'weapons', 'soon', 'history', 'one', 'interested', 'including', 'wars', 'zeppelin', 'adopted', 'franco', 'since', 'militaries', 'organizations', 'century', 'powered', 'flyer', 'retired', 'fixed', 'purchased', 'insurrectionary', 'established', 'american', 'mz', 'aeronautical', 'throughout', 'use', 'becom', 'either', 'lighter', 'corps', 'developed', 'ii', 'french', 'unit', 'two', 'multiple', 'observation', 'research', 'carried', 'last', 'well', 'major', 'roles', 'distribution', 'type', 'balloons', 'practical', 'used', 'may', 'procured', 'feature', 'aerostatic', 'seat', 'combat', 'air', 'raids', 'airships', 'see', 'using', 'battle', 'navy', 'u', 'fleurus', 'forces', 'carry', 'wright', 'defense', 'first', 'function', 'british', 'aerial', 'heavier', 'k', 'support', 'balloon', 'personnel', 'equipment', 'countries', 'operated', 'german', 'mainly', 'rigid', 'wing', 'napoleonic', 'development', 'designed', 'propaganda', 'aircraft'}
# unique word {'perform', 'speech', 'programs', 'methods', 'days', 'order', 'x', 'known', 'model', 'build', 'across', 'mathematical', 'strategies', 'set', 'also', 'training', 'th', 'decisions', 'obvious', 'work', 'every', 'working', 'artificial', 'times', 'related', 'predictive', 'sun', 'statistical', 'implementations', 'intelligence', 'building', 'study', 'exist', 'needed', 'improve', 'machine', 'email', 'devoted', 'without', 'predictions', 'mimics', 'difficult', 'involves', 'explicitly', 'conventional', 'past', 'let', 'theory', 'provided', 'learn', 'separate', 'based', 'computer', 'optimization', 'domains', 'medicine', 'since', 'rose', 'worked', 'sometimes', 'analytics', 'tomorrow', 'species', 'inferences', 'focuses', 'application', 'black', 'families', 'machines', 'broad', 'future', 'use', 'chance', 'wide', 'mining', 'making', 'recognition', 'field', 'business', 'make', 'applications', 'focusing', 'continue', 'last', 'well', 'analysis', 'problems', 'biological', 'sample', 'statistics', 'understanding', 'filtering', 'nuanced', 'used', 'morning', 'undiscovered', 'programmed', 'neural', 'ml', 'probably', 'unfeasible', 'using', 'computers', 'learning', 'rise', 'color', 'seen', 'performance', 'develop', 'computational', 'overview', 'brain', 'basis', 'leverage', 'unsupervised', 'subfield', 'subset', 'exploratory', 'agriculture', 'networks', 'closely', 'tasks', 'swans', 'vision', 'data', 'algorithms', 'variants', 'variety', 'referred', 'way', 'likely', 'delivers', 'geographically'}

# %%
# save the trained model to hard disk
nb_classifier.save_model('naive_payes_model.pkl')

# load the trained model from hard disk
nb_classifier.load_model('naive_payes_model.pkl')

# %%
# make predictions on the test data
predictions = nb_classifier.predict(test_data)

# print the predictions
for doc, predicted_label, actual_label in predictions:
    print(f"\n\nPredicted label: {predicted_label} -> Actual label: {actual_label} \n\n Document: \n\n{doc}")
# Out:
# unique word {'gravity', 'model', 'airfoil', 'centuries', 'place', 'able', 'common', 'th', 'usage', 'vehicles', 'thrust', 'pilot', 'flight', 'times', 'flown', 'remotely', 'paramotors', 'criteria', 'counters', 'activity', 'crewed', 'building', 'safe', 'whereas', 'took', 'direct', 'include', 'manned', 'hot', 'self', 'examples', 'history', 'stories', 'fly', 'including', 'gliders', 'ascent', 'designing', 'cent', 'different', 'descent', 'engines', 'aviation', 'airplanes', 'controlled', 'flying', 'classified', 'vehicle', 'either', 'developed', 'larger', 'aeronautics', 'craft', 'blimps', 'onboard', 'type', 'many', 'balloons', 'human', 'surrounds', 'static', 'may', 'modern', 'go', 'cases', 'unmanned', 'air', 'force', 'airships', 'downward', 'dynamic', 'using', 'computers', 'helicopters', 'called', 'science', 'first', 'aerial', 'propulsion', 'support', 'back', 'others', 'gaining', 'however', 'lift', 'aircraft'}
# Probability of word 'gravity' given label 'planes': 0.0008378718056137411
# Probability of word 'model' given label 'planes': 0.0012568077084206116
# Probability of word 'model' given label 'tech': 0.007518796992481203
# Probability of word 'airfoil' given label 'planes': 0.0008378718056137411
# Probability of word 'centuries' given label 'planes': 0.0012568077084206116
# Probability of word 'place' given label 'planes': 0.0012568077084206116
# Probability of word 'able' given label 'planes': 0.0008378718056137411
# Probability of word 'common' given label 'planes': 0.0008378718056137411
# Probability of word 'th' given label 'planes': 0.0016757436112274822
# Probability of word 'th' given label 'tech': 0.007518796992481203
# Probability of word 'usage' given label 'planes': 0.0008378718056137411
# Probability of word 'vehicles' given label 'planes': 0.0008378718056137411
# Probability of word 'thrust' given label 'planes': 0.0020946795140343527
# Probability of word 'pilot' given label 'planes': 0.0020946795140343527
# Probability of word 'flight' given label 'planes': 0.0041893590280687055
# Probability of word 'times' given label 'planes': 0.0016757436112274822
# Probability of word 'times' given label 'tech': 0.007518796992481203
# Probability of word 'flown' given label 'planes': 0.0008378718056137411
# Probability of word 'remotely' given label 'planes': 0.0008378718056137411
# Probability of word 'paramotors' given label 'planes': 0.0008378718056137411
# Probability of word 'criteria' given label 'planes': 0.0008378718056137411
# Probability of word 'counters' given label 'planes': 0.0008378718056137411
# Probability of word 'activity' given label 'planes': 0.0008378718056137411
# Probability of word 'crewed' given label 'planes': 0.0008378718056137411
# Probability of word 'building' given label 'planes': 0.0016757436112274822
# Probability of word 'building' given label 'tech': 0.007518796992481203
# Probability of word 'safe' given label 'planes': 0.0012568077084206116
# Probability of word 'whereas' given label 'planes': 0.0008378718056137411
# Probability of word 'took' given label 'planes': 0.0012568077084206116
# Probability of word 'direct' given label 'planes': 0.0012568077084206116
# Probability of word 'include' given label 'planes': 0.0012568077084206116
# Probability of word 'manned' given label 'planes': 0.0008378718056137411
# Probability of word 'hot' given label 'planes': 0.0012568077084206116
# Probability of word 'self' given label 'planes': 0.0012568077084206116
# Probability of word 'examples' given label 'planes': 0.0008378718056137411
# Probability of word 'history' given label 'planes': 0.002932551319648094
# Probability of word 'stories' given label 'planes': 0.0008378718056137411
# Probability of word 'fly' given label 'planes': 0.0012568077084206116
# Probability of word 'including' given label 'planes': 0.0016757436112274822
# Probability of word 'gliders' given label 'planes': 0.0008378718056137411
# Probability of word 'ascent' given label 'planes': 0.0008378718056137411
# Probability of word 'designing' given label 'planes': 0.0008378718056137411
# Probability of word 'different' given label 'planes': 0.0012568077084206116
# Probability of word 'descent' given label 'planes': 0.0008378718056137411
# Probability of word 'engines' given label 'planes': 0.0020946795140343527
# Probability of word 'aviation' given label 'planes': 0.0020946795140343527
# Probability of word 'airplanes' given label 'planes': 0.0012568077084206116
# Probability of word 'controlled' given label 'planes': 0.0016757436112274822
# Probability of word 'flying' given label 'planes': 0.0016757436112274822
# Probability of word 'classified' given label 'planes': 0.0008378718056137411
# Probability of word 'vehicle' given label 'planes': 0.0020946795140343527
# Probability of word 'either' given label 'planes': 0.0016757436112274822
# Probability of word 'developed' given label 'planes': 0.0025136154168412233
# Probability of word 'larger' given label 'planes': 0.0008378718056137411
# Probability of word 'aeronautics' given label 'planes': 0.0008378718056137411
# Probability of word 'craft' given label 'planes': 0.0008378718056137411
# Probability of word 'blimps' given label 'planes': 0.0008378718056137411
# Probability of word 'onboard' given label 'planes': 0.0008378718056137411
# Probability of word 'type' given label 'planes': 0.0025136154168412233
# Probability of word 'many' given label 'planes': 0.0012568077084206116
# Probability of word 'balloons' given label 'planes': 0.0012568077084206116
# Probability of word 'human' given label 'planes': 0.0008378718056137411
# Probability of word 'surrounds' given label 'planes': 0.0008378718056137411
# Probability of word 'static' given label 'planes': 0.0008378718056137411
# Probability of word 'may' given label 'planes': 0.0033514872224549644
# Probability of word 'modern' given label 'planes': 0.0012568077084206116
# Probability of word 'go' given label 'planes': 0.0008378718056137411
# Probability of word 'cases' given label 'planes': 0.0008378718056137411
# Probability of word 'unmanned' given label 'planes': 0.0008378718056137411
# Probability of word 'air' given label 'planes': 0.003770423125261835
# Probability of word 'force' given label 'planes': 0.0012568077084206116
# Probability of word 'airships' given label 'planes': 0.0012568077084206116
# Probability of word 'downward' given label 'planes': 0.0008378718056137411
# Probability of word 'dynamic' given label 'planes': 0.0008378718056137411
# Probability of word 'using' given label 'planes': 0.0020946795140343527
# Probability of word 'using' given label 'tech': 0.007518796992481203
# Probability of word 'computers' given label 'planes': 0.0008378718056137411
# Probability of word 'computers' given label 'tech': 0.007518796992481203
# Probability of word 'helicopters' given label 'planes': 0.0008378718056137411
# Probability of word 'called' given label 'planes': 0.0025136154168412233
# Probability of word 'science' given label 'planes': 0.0008378718056137411
# Probability of word 'first' given label 'planes': 0.0033514872224549644
# Probability of word 'aerial' given label 'planes': 0.0012568077084206116
# Probability of word 'propulsion' given label 'planes': 0.0016757436112274822
# Probability of word 'support' given label 'planes': 0.0016757436112274822
# Probability of word 'back' given label 'planes': 0.0012568077084206116
# Probability of word 'others' given label 'planes': 0.0008378718056137411
# Probability of word 'gaining' given label 'planes': 0.0008378718056137411
# Probability of word 'however' given label 'planes': 0.0020946795140343527
# Probability of word 'lift' given label 'planes': 0.0012568077084206116
# Probability of word 'aircraft' given label 'planes': 0.004608294930875576
# unique word {'perform', 'broad', 'predictions', 'ml', 'speech', 'methods', 'order', 'difficult', 'known', 'unfeasible', 'explicitly', 'model', 'build', 'conventional', 'mathematical', 'using', 'computers', 'let', 'learning', 'email', 'set', 'seen', 'wide', 'making', 'theory', 'recognition', 'learn', 'performance', 'training', 'make', 'decisions', 'applications', 'develop', 'based', 'computational', 'computer', 'optimization', 'artificial', 'related', 'leverage', 'domains', 'subfield', 'subset', 'medicine', 'agriculture', 'closely', 'sample', 'statistics', 'tasks', 'understanding', 'filtering', 'vision', 'data', 'algorithms', 'statistical', 'used', 'intelligence', 'building', 'study', 'focuses', 'variety', 'application', 'needed', 'improve', 'delivers', 'machine', 'field', 'devoted', 'programmed', 'machines', 'without'}
# Probability of word 'perform' given label 'tech': 0.007518796992481203
# Probability of word 'broad' given label 'planes': 0.0008378718056137411
# Probability of word 'broad' given label 'tech': 0.007518796992481203
# Probability of word 'predictions' given label 'tech': 0.007518796992481203
# Probability of word 'ml' given label 'tech': 0.007518796992481203
# Probability of word 'speech' given label 'tech': 0.007518796992481203
# Probability of word 'methods' given label 'planes': 0.0008378718056137411
# Probability of word 'methods' given label 'tech': 0.007518796992481203
# Probability of word 'order' given label 'planes': 0.0008378718056137411
# Probability of word 'order' given label 'tech': 0.007518796992481203
# Probability of word 'difficult' given label 'tech': 0.007518796992481203
# Probability of word 'known' given label 'planes': 0.0020946795140343527
# Probability of word 'known' given label 'tech': 0.007518796992481203
# Probability of word 'unfeasible' given label 'tech': 0.007518796992481203
# Probability of word 'explicitly' given label 'tech': 0.007518796992481203
# Probability of word 'model' given label 'planes': 0.0012568077084206116
# Probability of word 'model' given label 'tech': 0.007518796992481203
# Probability of word 'build' given label 'tech': 0.007518796992481203
# Probability of word 'conventional' given label 'tech': 0.007518796992481203
# Probability of word 'mathematical' given label 'tech': 0.007518796992481203
# Probability of word 'using' given label 'planes': 0.0020946795140343527
# Probability of word 'using' given label 'tech': 0.007518796992481203
# Probability of word 'computers' given label 'planes': 0.0008378718056137411
# Probability of word 'computers' given label 'tech': 0.007518796992481203
# Probability of word 'let' given label 'tech': 0.007518796992481203
# Probability of word 'learning' given label 'tech': 0.007518796992481203
# Probability of word 'email' given label 'tech': 0.007518796992481203
# Probability of word 'set' given label 'planes': 0.0008378718056137411
# Probability of word 'set' given label 'tech': 0.007518796992481203
# Probability of word 'seen' given label 'tech': 0.007518796992481203
# Probability of word 'wide' given label 'planes': 0.0012568077084206116
# Probability of word 'wide' given label 'tech': 0.007518796992481203
# Probability of word 'making' given label 'tech': 0.007518796992481203
# Probability of word 'theory' given label 'tech': 0.007518796992481203
# Probability of word 'recognition' given label 'tech': 0.007518796992481203
# Probability of word 'learn' given label 'tech': 0.007518796992481203
# Probability of word 'performance' given label 'tech': 0.007518796992481203
# Probability of word 'training' given label 'planes': 0.0008378718056137411
# Probability of word 'training' given label 'tech': 0.007518796992481203
# Probability of word 'make' given label 'planes': 0.0012568077084206116
# Probability of word 'make' given label 'tech': 0.007518796992481203
# Probability of word 'decisions' given label 'tech': 0.007518796992481203
# Probability of word 'applications' given label 'planes': 0.0012568077084206116
# Probability of word 'applications' given label 'tech': 0.007518796992481203
# Probability of word 'develop' given label 'planes': 0.0008378718056137411
# Probability of word 'develop' given label 'tech': 0.007518796992481203
# Probability of word 'based' given label 'planes': 0.0016757436112274822
# Probability of word 'based' given label 'tech': 0.007518796992481203
# Probability of word 'computational' given label 'tech': 0.007518796992481203
# Probability of word 'computer' given label 'tech': 0.007518796992481203
# Probability of word 'optimization' given label 'tech': 0.007518796992481203
# Probability of word 'artificial' given label 'tech': 0.007518796992481203
# Probability of word 'related' given label 'tech': 0.007518796992481203
# Probability of word 'leverage' given label 'tech': 0.007518796992481203
# Probability of word 'domains' given label 'tech': 0.007518796992481203
# Probability of word 'subfield' given label 'tech': 0.007518796992481203
# Probability of word 'subset' given label 'tech': 0.007518796992481203
# Probability of word 'medicine' given label 'tech': 0.007518796992481203
# Probability of word 'agriculture' given label 'tech': 0.007518796992481203
# Probability of word 'closely' given label 'planes': 0.0008378718056137411
# Probability of word 'closely' given label 'tech': 0.007518796992481203
# Probability of word 'sample' given label 'tech': 0.007518796992481203
# Probability of word 'statistics' given label 'tech': 0.007518796992481203
# Probability of word 'tasks' given label 'tech': 0.007518796992481203
# Probability of word 'understanding' given label 'tech': 0.007518796992481203
# Probability of word 'filtering' given label 'tech': 0.007518796992481203
# Probability of word 'vision' given label 'tech': 0.007518796992481203
# Probability of word 'data' given label 'planes': 0.0008378718056137411
# Probability of word 'data' given label 'tech': 0.007518796992481203
# Probability of word 'algorithms' given label 'tech': 0.007518796992481203
# Probability of word 'statistical' given label 'tech': 0.007518796992481203
# Probability of word 'used' given label 'planes': 0.0033514872224549644
# Probability of word 'used' given label 'tech': 0.007518796992481203
# Probability of word 'intelligence' given label 'tech': 0.007518796992481203
# Probability of word 'building' given label 'planes': 0.0016757436112274822
# Probability of word 'building' given label 'tech': 0.007518796992481203
# Probability of word 'study' given label 'planes': 0.0008378718056137411
# Probability of word 'study' given label 'tech': 0.007518796992481203
# Probability of word 'focuses' given label 'tech': 0.007518796992481203
# Probability of word 'variety' given label 'planes': 0.0008378718056137411
# Probability of word 'variety' given label 'tech': 0.007518796992481203
# Probability of word 'application' given label 'planes': 0.0008378718056137411
# Probability of word 'application' given label 'tech': 0.007518796992481203
# Probability of word 'needed' given label 'tech': 0.007518796992481203
# Probability of word 'improve' given label 'tech': 0.007518796992481203
# Probability of word 'delivers' given label 'tech': 0.007518796992481203
# Probability of word 'machine' given label 'planes': 0.0008378718056137411
# Probability of word 'machine' given label 'tech': 0.007518796992481203
# Probability of word 'field' given label 'tech': 0.007518796992481203
# Probability of word 'devoted' given label 'tech': 0.007518796992481203
# Probability of word 'programmed' given label 'tech': 0.007518796992481203
# Probability of word 'machines' given label 'tech': 0.007518796992481203
# Probability of word 'without' given label 'planes': 0.0008378718056137411
# Probability of word 'without' given label 'tech': 0.007518796992481203
#
#
# Predicted label: planes -> Actual label: planes
#
#  Document:
#
# aircraft vehicle able fly gaining support air counters force gravity using either static lift dynamic lift airfoil cases direct downward thrust engines common examples aircraft include airplanes helicopters airships including blimps gliders paramotors hot air balloons human activity surrounds aircraft called aviation science aviation including designing building aircraft called aeronautics crewed aircraft flown onboard pilot whereas unmanned aerial vehicles may remotely controlled self controlled onboard computers aircraft may classified different criteria lift type aircraft propulsion usage others history flying model craft stories manned flight go back many centuries however first manned ascent safe descent modern times took place larger hot air balloons developed th cent
#
#
# Predicted label: planes -> Actual label: tech
#
#  Document:
#
# machine learning ml field devoted understanding building methods let machines learn methods leverage data improve computer performance set tasks seen broad subfield artificial intelligence machine learning algorithms build model based sample data known training data order make predictions decisions without explicitly programmed machine learning algorithms used wide variety applications medicine email filtering speech recognition agriculture computer vision difficult unfeasible develop conventional algorithms perform needed tasks subset machine learning closely related computational statistics focuses making predictions using computers machine learning statistical learning study mathematical optimization delivers methods theory application domains field machine learning
